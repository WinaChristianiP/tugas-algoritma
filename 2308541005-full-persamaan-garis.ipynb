# %%
#Akan dibuat persamaan garis jika diketahui :
#1.Jika diketahui dua titik
#2.Jika diektahui 1 gradien dan satu titik
#3.Jika diketahui persamaan ax+by=c

import numpy as np
import matplotlib.pyplot as plt

print("==========PERSMAAN GARIS==========")
tanya_kasus_05 = float(input("Kasus berapa yang akan anda kerjakan? : "))
#1.Jika diketahui dua tiitk
if tanya_kasus_05 == 1:
    print("Masing-masing garis akan melewati dua titik")
    w_05 = float(input("Masukkan nilai w : "))
    i_05 = float(input("Masukkan nilai i : "))
    n_05 = float(input("Masukkan nilai n : "))
    a_05 = float(input("Masukkan nilai a : "))

    c_05 = float(input("Masukkan nilai c : "))
    h_05 = float(input("Masukkan nilai h : "))
    r_05 = float(input("Masukkan nilai r : "))
    s_05 = float(input("Masukkan nilai s : "))

    #Selanjutnya akan dicari gradien dari masing-masing garis
    m_1_05 = (a_05-i_05)/(n_05-w_05)
    m_2_05 = (h_05-h_05)/(r_05-c_05)

    #Persamaan garis pertama adalah y=m_1_05(x-w_05)+i_05 = m_1_05x-m_1_05w_05+i_05
    #Persamaan garis kedua adalah y=m_2_05(x-c_05)+h_05 = m_2_05x-m_2_05c_05+h_05
    #Selanjutnya akan dicari titik potong 
    tipot_1_05 = -m_1_05* w_05+i_05
    tipot_2_05 = -m_2_05* c_05+h_05
    #Memperoleh Persamaan garis
    print("Persamaan garis pertama adalah y ={:.3f}x+{:.3f}".format(m_1_05,tipot_1_05))
    print("Persamaan garis kedua adalah y ={:.3f}x+{:.3f}".format(m_2_05,tipot_2_05))

    if m_1_05 == m_2_05:
        print("Kemungkinan garis sejajar atau berhimpitan")
        if tipot_1_05 == tipot_2_05 :
            print("Garis yang terbentuk akan berhimpit, sehingga terdapat tak hingga solusi") #garis berhimpit
        x_05 = np.linspace(-5,5,100)
        plt.plot(x_05,m_1_05*(x_05-w_05)+i_05,color="yellow",label="y={}(x-{})+{}".format(m_1_05,w_05,i_05))
        plt.plot(x_05,m_2_05*(x_15-c_05)+h_05,color="grey", label="y={}(x-{})+{}".format(m_2_05,c_05,h_05))
        plt.axvline(x = 0,color='black')
        plt.axhline(y = 0,color='black')
        plt.title("Gambar Persamaan Garis Berhimpit")
        plt.show()
        else:
            print("Dapat dilihat garisnya sejajar, sehingga tidak memiliki solusi") #garisnya sejajar
        x_05 = np.linspace(-5,5,100)
        plt.plot(x_05,m_1_05*(x_05-w_05)+i_05,color="yellow",label="y={}(x-{})+{}".format(m_1_05,w_05,i_05))
        plt.plot(x_05,m_2_05*(x_15-c_05)+h_05,color="grey", label="y={}(x-{})+{}".format(m_2_05,c_05,h_05))
        plt.axvline(x = 0,color='black')
        plt.axhline(y = 0,color='black')
        plt.title("Gambar Persamaan Garis Sejajar")
        plt.show()
    else:
        print("Gradiennya tidak sama, sehingga garisnya berpotongan")
        print("Ayo kita lihat gambar garisnya")
        #mencari titik potong persamaan garis (tipot_x_05,tipot_y_05)
        tipot_x_05 = (m_1_05 * w_05-i_05-m_2_05 * c_05+h_05)/(m_1_05-m_2_05) #Tipot 1
        tipot_y_05 = m_2_05 * (tipot_x_05-c_05)+h_05 #Tipot 2
        print("Maka titik potong kedua garis adalah ({},{})".format(tipot_x_05,tipot_y_15))
        x_05 = np.linspace(tipot_x_05-5,tipot_x_05+5,100)
        plt.plot(x_05,m_1_05*(x_05-w_05)+i_05,color='grey',label="y={}(x-{})+{}".format(m_1_05,w_05,i_05))
        plt.plot(x_05,m_2_05*(x_15-c_05)+h_05,color='pink',label="y={}(x-{})+{}".format(m_2_05,c_05,h_05))
        plt.plot(tipot_x_05,tipot_y_05,color="black",marker="o",markersize=2)
        plt.axvline(x = 0,color='black')
        plt.axhline(y = 0,color='black')
        plt.title("Gambar Persamaan Garis Berpotongan")
        plt.show()
        
#Kondisi ke 2
elif tanya_kasus_05 == 2:
    print("Masing-masing garis diketahui gradien dan titik yang dilewati.") 
    m_1_05 = float(input("Gradien dari garis pertama adalah ")) # masukkan nilai gradien 1
    w_05 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah "))
    i_05 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah "))
    print("Persamaan garis pertama adalah y={}(x-{})+{}".format(m_1_05,w_05,i_05))
               
    m_2_05 = float(input("Gradien dari garis kedua adalah ")) # masukkan nilai gradien 2
    c_05 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah "))
    h_05 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah "))
    print("Persamaan garis kedua adalah y={}(x-{})+{}".format(m_2_05,c_05,h_05))
    
    #Selanjutnya akan dicari titik potong 
    tipot_1_05 = -m_1_05 * w_05 + i_05
    tipot_2_05 = -m_2_05 * c_05 + h _05
    print("Persamaan garis pertama adalah y={}x+{}".format(m_1_05,tipot_1_05))
    print("Persamaan garis kedua adalah y={}x+{}\n".format(m_2_05,tipot_2_05))
    if m_1_05 == m_2_05:
        print("Diperoleh gradiennya sama, jadi kemungkinan garisnya sejajar atau berhimpit")
        if tipot_1_05 == tipot_2_05:
            print("Akan dihasilkan garis yang berhimpit, sehingga solusinya banyak")
            x_05 = np.linspace(-10,10,100)
            plt.plot(x_05,m_1_05*(x_05-w_05)+i_05,color="red", label = "y={}x+{}".format(m_1_05,tipot_1_05))
            plt.plot(x_05,m_2_05*(x_05-c_05)+h_05,color="lightblue", label = "y={}x+{}".format(m_2_05,tipot_2_05))
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis")
            plt.show()
        else:
            print("Apakah garisnya sejajar?")
            x_05 = np.linspace(-10,10,100)
            plt.plot(x_05,m_1_05*(x_05-w_05)+i_05,color="green", label = "y={}x+{}".format(m_1_05,tipot_1_05))
            plt.plot(x_05,m_2_05*(x_05-c_05)+h_05,color="pink", label = "y={}x+{}".format(m_2_05,tipot_2_05))
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis Sejajar")
            plt.show()
    else:
        print("Gradiennya tidak samaa, jadi sudah pasti garisnya berpotongan di satu titik")
        #mencari titik potong persamaan garis (tp_x_15,tp_y_15)
        tipot_x_05 = (m_1_05*w_05-i_05-m_2_05*c_05+h_05)/(m_1_05-m_2_05) #tipot garis 1
        tipot_y_05 = m_2_05*(tipot_x_05-c_05)+h_05 #tipot garis 2
        print ("Sehingga titik potong kedua garis adalah ({},{})".format(tipot_x_05,tipot_y_05))
        x_05 = np.linspace(tipot_x_05-5,tipot_x_05+5,100)
        plt.plot(x_05,m_1_05*(x_05-w_05)+i_05,color='pink',label="y={}(x-{})+{}".format(m_1_05,w_05,i_05))
        plt.plot(x_05,m_2_05*(x_05-c_05)+h_05,color='skyblue',label="y={}(x-{})+{}".format(m_2_05,c_15,h_15))
        plt.plot(tipot_x_05,tipot_y_05,color="black",marker="o",markersize=3)
        plt.axvline(x=0,color='black')
        plt.axhline(y=0,color='black')
        plt.title("Gambar Persamaan Garis")
        plt.show()

#penyelesaian kasus 3
elif tanya_kasus_05 == 3:
    print("Kedua garis memenuhi persamaan berbentuk wx+iy=n dan cx+hy=r.")
    #Masukkan nilai elemen-elemen pembuat persamaan kedua
    w_05 = float(input("Koefisien dari x pada garis pertama adalah : "))
    i_05 = float(input("Koefisien dari y pada garis pertama adalah : "))
    n_05 = float(input("Konstanta dari garis pertama adalah : "))
    #Masukkan elemen-elemen pembuat persamaan kedua
    c_05 = float(input("Koefisien dari x pada garis kedua adalah : "))
    h_05 = float(input("Koefisien dari y pada garis kedua adalah : "))
    r_05 = float(input("Konstanta dari garis kedua adalah : "))
    #Akan dicari gradien kedua persamaan garis dari titik-titik yang diketahui
    m_1_05 = ((-w_05)/i_05) # Gradien garis pertama
    m_2_015= (-c_05)/(h_05) # Gradien garis kedua

    #mencari titik potong garis terhadap sumbu y
    tipot_1_05 = n_05/i_15 # Titik potong garis pertama terhadap sumbu y
    tipot_2_15 = r_15/h_15 # titik potong garis kedua terhadap sumbu y garis kedua

    print("persamaan garis 1 adalah : y= ({}x)+{}".format(m_1_05,tipot_1_05))
    print("persamaan garis 2 adalah : y= ({}x)+{}".format(m_2_05,tipot_2_05))

    if m_1_05 == m_2_05:
        print("Diperoleh gradien keduanya sama, jadi kemungkinan garisnya sejajar atau berhimpit")
        if tipot_1_05 == tipot_2_05:
            print("Lihat garisnya berhimpit maka banyak solusi penyelesaian deh")
            x_05 = np.linspace(-10,10,100)
            plt.plot(x_05,(m_1_05*x_05)+tipot_1_05,color="blue", label="line 1")
            plt.plot(x_05,(m_2_05*x_05)+tipot_2_05,color="pink",label="line 2")
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis")
            plt.show()
        else:
            print("Lihat garisnya sejajar sehingga tidak memiliki solusi penyelesaian deh")
            x_05 = np.linspace(-5,5,100)
            plt.plot(x_05,(m_1_05*x_05)+tipot_1_05,color="grey", label="line 1")
            plt.plot(x_05,(m_2_05*x_05)+tipot_2_05,color="pink",label="line 2")
            plt.axvline(x=0,color='black')
            plt.axhline(y=0,color='black')
            plt.title("Gambar Persamaan Garis")
            plt.show()
    else:
        print("Gradiennya tidak samaa, jadi sudah pasti garisnya berpotongan di satu titik.")
        print("ayo kita hitung titik potongnya dengan matriks! ")
        #tentukan matriks koefisien A dan matriks konstanta B
        J_05 = np.array([[w_05, c_05], [i_05,h_15]])
        S_05 = np.array([n_05, r_05])
        print("Matriks dari koefisien x dan y yaitu : ", J_05)
        print("Matriks konstanta dari kedua persamaan garis yaitu :", S_15)
        #untuk menghitung titik potong dari dua persamaan diatas, maka akan dihitung invers matriks J dikali dengan Matriks S
        #akan dihitung invers dari matriks J dengan rumus numpy
        inv_05 = np.linalg.inv(J_05)
        print("Invers dari Matriks J yaitu:", inv_05)
        # Selesaikan sistem persamaan linear menggunakan fungsi np.linalg.dot
        xy_05 = np.dot((inv_05),(S_05))
        print("titik potongnya adalah :  [x,y]=", xy_05)
        #ayo gambar persamaaan garisnya
        x_05 = np.linspace(xy_05-5,xy_05+5,100)
        plt.plot(x_05,(m_1_05*x_05)+tipot_1_05,color="pink",label="y= ({}x)+{}".format(m_1_05,tipot_1_05))
        plt.plot(x_05,(m_2_05*x_05)+tipot_2_05,color="yellow",label="y= ({}x)+{}".format(m_2_05,tipot_2_05))
        plt.axvline(x=0,color='black')
        plt.axhline(y=0,color='black')
        plt.title("Gambar Persamaan Garis")
        plt.show()
else:
    print("Ayo diperhatikan lagi!!!! :) ")
# Out:
#   Cell In[3], line 48
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
#Akan dibuat persamaan garis jika diketahui :
#1.Jika diketahui dua titik
#2.Jika diektahui satu gradien dan satu titik
#3.Jika diketahui persamaan ax+by=c

#2.Jika diketahui satu gradien dan satu titik
import numpy as np
import matplotlib.pyplot as plt
print("==========PERSMAAN GARIS==========")
print("Masing-masing garis diketahui gradien dan titik yang dilewati.") 
m_1_05 = float(input("Gradien dari garis pertama adalah ")) # masukkan nilai gradien 1
a_05 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah "))
b_05 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah "))
print("Persamaan garis pertama adalah y={}(x-{})+{}".format(m_1_05,a_05,b_05))
               
m_2_05 = float(input("Gradien dari garis kedua adalah ")) # masukkan nilai gradien 2
c_05 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah "))
d_05 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah "))
print("Persamaan garis kedua adalah y={}(x-{})+{}".format(m_2_05,c_05,d_05))
    
c_1_05 = -m_1_05 * a_05 + b_05 #Tipot garis 1
c_2_05 = -m_2_05 * c_05 + d_05 #Tipot garis 2
    
if m_1_05 == m_2_05:
    print("Kedua garis sejajar")
    if c_1 == c_2:
        print("Terdapat tak berhingga banyaknya solusi")
    else:
            print("Tidak terdapat solusi")
else:
    print("Kedua garis akan berpotongan di satu titik.")
# Out:
# ==========PERSMAAN GARIS==========
# Masing-masing garis diketahui gradien dan titik yang dilewati.
# Gradien dari garis pertama adalah  -1
# Nilai x dari titik yang dilewati oleh garis pertama adalah  1
# Nilai y dari titik yang dilewati oleh garis pertama adalah  2
# Persamaan garis pertama adalah y=-1.0(x-1.0)+2.0
# Gradien dari garis kedua adalah  3
# Nilai x dari titik yang dilewati oleh garis kedua adalah  4
# Nilai y dari titik yang dilewati oleh garis kedua adalah  1
# Persamaan garis kedua adalah y=3.0(x-4.0)+1.0
# Kedua garis akan berpotongan di satu titik.
