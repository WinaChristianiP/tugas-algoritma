# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#tipe 2.12
senyawa_alkana_05 = ['Metana','Etana','Propana','Butana','Pentana','Heksana','Heptana','Oktana','Nonana',]
print(senyawa_alkana_05[4])
print(senyawa_alkana_05[-2])
print(senyawa_alkana_05[6])
yuyu_05 = print(" ")
senyawa_alkana_05[8:9] = 'Nonana', 'Dekana'
print(senyawa_alkana_05)
yuyu_05 = print(" ")
senyawa_alkana_05 [7:9] = 'Oktana','Nonana','Pentena'
print(senyawa_alkana_05)
print("Berdasarkan daftar senyawa alkana diatas, maka jawablah pertanyaan dibawah ini!")
pertanyaan_05 = input("Apakah menurut anda nama senyawa diatas sudah tepat semua pada golongan alkana?: ")
if pertanyaan_05 == "Tidak" :
    print("Sepertinya anda mengetahuinya dengan baik!")
elif pertanyaan_05 == "Iya" :
    print ("Hai kawan, sepertinya anda harus membaca kembali materi senyawa hidrogen pada pembelajaran kimia")
# Out:
# Pentana
# Oktana
# Heptana
#
# ['Metana', 'Etana', 'Propana', 'Butana', 'Pentana', 'Heksana', 'Heptana', 'Oktana', 'Nonana', 'Dekana']
#
# ['Metana', 'Etana', 'Propana', 'Butana', 'Pentana', 'Heksana', 'Heptana', 'Oktana', 'Nonana', 'Pentena', 'Dekana']
# Berdasarkan daftar senyawa alkana diatas, maka jawablah pertanyaan dibawah ini!
# Apakah menurut anda nama senyawa diatas sudah tepat semua pada golongan alkana?:  Iya
# Hai kawan, sepertinya anda harus membaca kembali materi senyawa hidrogen pada pembelajaran kimia

# %%
#tipe 2.13
besaran_pokok_05 = ['Massa', 'Intensitas Cahaya', 'Waktu', 'Kuat Arus', 'Jumlah Zat']
print(besaran_pokok_05[2])
yuyu_05 = print(" ")
besaran_pokok_05.insert(2, 'Suhu',)
print(besaran_pokok_05)
yuyu_05 = print(" ")
besaran_pokok_05.remove('Jumlah Zat')
print(besaran_pokok_05)
yuyu_05 = print(" ")
print("Luas" in besaran_pokok_05)
print("Kuat Arus" in besaran_pokok_05)
print(len(besaran_pokok_05))
yuyu_05 = print(" ")
pertanyaan_05 = input("Besaran pokok apa yang belum disebutkan?")
if pertanyaan_05 == "Panjang" :
    print("Yeayy,Kamu benar sekali!!" )
elif pertanyaan_05 != "Panjang"  :
    print ("Kamu salah, coba ingat-ingat lagi")
# Out:
# Waktu
#
# ['Massa', 'Intensitas Cahaya', 'Suhu', 'Waktu', 'Kuat Arus', 'Jumlah Zat']
#
# ['Massa', 'Intensitas Cahaya', 'Suhu', 'Waktu', 'Kuat Arus']
#
# False
# True
# 5
# Besaran pokok apa yang belum disebutkan? Panjang
# Yeayy,Kamu benar sekali!!

# %%
#tipe 2.14
#Pada sebuah kelas terdapat beberapa limas sebagai bahan praktek pada saat pembelajaran bangun ruang limas
limas_05 = ['Limas segitiga', 'Limas segiempat', 'Limas segilima', 'Limas segienam']
for jenis in limas_05 :
    print (jenis)
# Out:
# Limas segitiga
# Limas segiempat
# Limas segilima
# Limas segienam

# %%
#tipe 2.14
besaran_turunan_05 = ['Luas', 'Volume', 'Gaya','Usaha','Daya','Kecepatan','Percepatan']
i = 0
while i < len(besaran_turunan_05):
    print(besaran_turunan_05[i])
    i +=1
# Out:
# Luas
# Volume
# Gaya
# Usaha
# Daya
# Kecepatan
# Percepatan
