# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("Ari seorang kpopers")
print("Ia rajin menabung untuk membeli tiket konser boygroup favoritnya ")
print("Dalam beberapa waktu tabungan Ari terkumpul cukup banyak ")
print("Namun sayang, ia mengalami hal apes :) ")
print("Uangnya hilang tidak tahu dimana")
uang_Ari_di_tabungan_05 = input("Berapakah jumlah awal uang Ari di tabungan? ")
uang_Ari_hilang_05 = input ("Lalu berapa jumlah uang Ari yang hilang? ")
sisa_uang_05 = int (uang_Ari_di_tabungan_05) - int (uang_Ari_hilang_05)
print("Maka sisa uang Ari sekarang adalah Rp "+ str(sisa_uang_05))
print("AYAOK RIK SEMANAGAT LAGI NABUNGNYA")
# Out:
# Ari seorang kpopers
# Ia rajin menabung untuk membeli tiket konser boygroup favoritnya
# Dalam beberapa waktu tabungan Ari terkumpul cukup banyak
# Namun sayang, ia mengalami hal apes :)
# Uangnya hilang tidak tahu dimana
# Berapakah jumlah awal uang Ari di tabungan?  5500000
# Lalu berapa jumlah uang Ari yang hilang?  2000000
# Maka sisa uang Ari sekarang adalah Rp 3500000
# AYAOK RIK SEMANAGAT LAGI NABUNGNYA

# %%
print("----POTONGAN HARGA LEBARAN----")
print("Beberapa hari ini akan ada spesial potongan harga jika kamu belanja dalam jangka waktu dari tanggal 7 sampai 14")
print ("Tanggal berapa kamu ingin pergi?")
tanggal_05 = float(input("Aku akan pergi tanggal"))
if tanggal_05 >= 7 and tanggal_05 <= 9:
    print("Kamu akan mendapatkan potongan hingga 40% + 30%")
    print("Sepertinya kamu sangat bersemangat belanja saat mendengar tentang potongan harga!")
if tanggal_05 > 9 and tanggal_05 <= 10:
    print("Kamu akan mendapatkan potongan 30%")
    print("Potongan harga yang kamu dapatkan di hari ini cukup memuaskan kan pastinya?")
if tanggal_05 > 10 and tanggal_05 <= 13:
    print("Kamu akan mendaptkan potongan 20%")
    print("Sepertinya kamu mendapatkan potongan yang cukup memuaskan")
    print("Namun apakah seharusnya kamu datang lebih cepat?")
if tanggal_05 == 14:
    print("Kamu akan mendapatkan potongan harga hingga 50% + 30%")
    print("Wah kamu memilih hari yang tepat karena kamu mendapatkan potongan harga yang cukup fantastis")
    print("Selamat berbelanja!!")
# Out:
# ----POTONGAN HARGA LEBARAN----
# Beberapa hari ini akan ada spesial potongan harga jika kamu belanja dalam jangka waktu dari tanggal 7 sampai 14
# Tanggal berapa kamu ingin pergi?
# Aku akan pergi tanggal 11
# Kamu akan mendaptkan potongan 20%
# Sepertinya kamu mendapatkan potongan yang cukup memuaskan
# Namun apakah seharusnya kamu datang lebih cepat?

# %%
print("----RISOL KAMPUS----")
print("Mari menghitung berapa keuntungan menjual risol di lingkungan kampus!")
#input data
modal_05 = input("Modal awal risol : ")
harga_jual_risol_05 = input("Harga jual risol per pcs adalah : ")
risol_terjual_05 = input("Jumlah Risol yang terjual : ")
total_jual_risol_05 = int(harga_jual_risol_05) * int(risol_terjual_05 )
keuntungan_jual_risol_05 = int(total_jual_risol_05) - int(modal_05)
print("Keuntungan penjualan risol adalah Rp " + str(keuntungan_jual_risol_05))
# Out:
# ----RISOL KAMPUS----
# Mari menghitung berapa keuntungan menjual risol di lingkungan kampus!
# Modal awal risol :  70000
# Harga jual risol per pcs adalah :  5000
# Jumlah Risol yang terjual :  40
# Keuntungan penjualan risol adalah Rp 130000
